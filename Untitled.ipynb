# %%
import pandas as pd

# %%
df = pd.read_html("https://fbref.com/en/comps/22/stats/Major-League-Soccer-Stats", attrs={"id":"stats_squads_standard_for"})[0]

# %%
df
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Squad               # Pl                Age
# 0          Atlanta Utd                 26               29.3
# 1               Austin                 20               28.4
# 2          CF Montréal                 28               24.5
# 3            Charlotte                 22               28.6
# 4         Chicago Fire                 26               26.6
# 5      Colorado Rapids                 27               26.0
# 6        Columbus Crew                 25               27.3
# 7          D.C. United                 27               26.6
# 8        FC Cincinnati                 24               27.7
# 9            FC Dallas                 26               27.4
# 10      Houston Dynamo                 28               27.4
# 11         Inter Miami                 27               29.0
# 12           LA Galaxy                 24               28.1
# ...
